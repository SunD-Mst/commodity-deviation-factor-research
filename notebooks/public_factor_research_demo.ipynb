# %% [markdown]
# # Public Factor Research Demo
#
# This notebook demonstrates the public, desensitized research workflow using mock data.

# %%
from pathlib import Path
import sys

project_root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(project_root / 'src'))

from factor_research_public import run_public_demo

result = run_public_demo()
result['event_summary']
